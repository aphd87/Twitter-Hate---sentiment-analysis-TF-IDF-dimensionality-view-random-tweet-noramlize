# %%
## ========================= For Data Manipulation =========================

# Multi-dimensional array objects and a Collection of routines for processing of array in domain of Linear Algebra, Fourier Transform, and Matrices.
import numpy as np

# Data Analysis and Manipulation tool
import pandas as pd

#Replace and substitute
import os, re

## ========================= For Visualization =========================

# To create 2-D plots from data stored in a variety of data structures including "Lists, Numpy Arrays, and Pandas Dataframes".
import matplotlib.pyplot as plt

# It is used for "Statistical plotting" in Python. 
# It is "built on top of Matplotlib" and provides "beautiful default styles and color palettes" to make statistical plots more attractive.
import seaborn as sns

# We want our plots to appear in the notebook
# %matplotlib inline  

# Em-bed/ Display Images or Pictures in jupyter notebook, stored locally, either via relative or absolute path.
from IPython.display import Image



## ========================= To Manipulate Files and Directories =========================

# "os" module in python provides functions for interacting with the operating system
import os



## ========================= Counter (gives back list) =========================
from collections import Counter



## ========================= For Outliers =========================

# ------------------------- Using "Scipy" Library -------------------------
from scipy import stats

# Define "Vector space"
# In a "loguniform" distribution, the log-transformed random variable is assumed to be uniformly distributed.
from scipy.stats import loguniform  # [pip install LogUniform]



## ========================= Model evaluators =========================

from sklearn.model_selection import train_test_split , GridSearchCV , cross_val_score
from sklearn.model_selection import StratifiedShuffleSplit , StratifiedKFold          ## For Stratified Sampling 
from sklearn import metrics
from sklearn.feature_extraction.text import TfidfVectorizer

# ------------------------- For Regression -------------------------

#from sklearn.metrics import mean_squared_error
#from sklearn.metrics import r2_score

# ------------------------- For Classification -------------------------
from sklearn import metrics
#from sklearn.metrics import auc
#from sklearn.metrics import plot_roc_curve
#from sklearn.metrics import roc_curve
#from sklearn.metrics import roc_auc_score
#from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
#from sklearn.metrics import precision_score, recall_score, f1_score



## ========================= Model Algorithms =========================

# ------------------------- For Regression -------------------------

#from sklearn.linear_model import LinearRegression
#from sklearn.linear_model import Ridge   ## Addresses multicollinearity issues
#from sklearn.linear_model import Lasso   ## Determines which variables should be retained in the model
#from sklearn.linear_model import ElasticNet
#from sklearn.tree import DecisionTreeRegressor
#from sklearn.ensemble import RandomForestRegressor
#from xgboost import XGBRegressor


# ------------------------- For Classification -------------------------

#from sklearn.ensemble import GradientBoostingClassifier
#from xgboost import XGBClassifier
#from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.svm import SVC
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.tree import ExtraTreeClassifier
#from sklearn.naive_bayes import GaussianNB



## ========================= Preprocessing of Raw Text using NLP =========================

# ------------------------- For NLP -------------------------

# Toolkit used to analyze and process large amounts of Natural Language Data  [pip install nltk]
import nltk


# ------------------------- For Tokenization -------------------------

# "Punkt" Sentence Tokenizer divides a "text into a list of sentences", by using an "unsupervised algorithm" to build a model for abbreviation words, collocations[In "corpus" linguistics, a collocation is a series of words or terms that "co-occur more often" than would be expected by chance], and words that start sentences.
# The NLTK data package includes a "pre-trained Punkt" tokenizer for "English".
# In General ,"Punkt" Library is used for "Tokenising sentences".
#nltk.download('punkt')

# Word Tokenization library is used to "Split words" in a sentence/Data.
from nltk import word_tokenize

# sentence tokenization library is used to "BREAKS a string of sentences" from Data.
# It detects sentence boundaries.
from nltk import sent_tokenize

# Tweet tokenization library is used to convert "stream of words into small small tokens" 
from nltk import TweetTokenizer


# ------------------------- For Stop-words Removal -------------------------

# In General ,"stopwords" library is used to return a "list of lowercase" stop words for the "English" language
nltk.download('stopwords')
from nltk.corpus import stopwords   # [pip install stop-words] -> Only if applicable


# ------------------------- For Text Normalization -------------------------

## Spelling Correction:- 

# It is a process of correcting word’s spelling by fixing the "word lengthening issue first" and then deal with "spelling mistakes".
# If using for the first time,install it by "pip-ing" it   [pip install autocorrect] 
# !pip install autocorrect
from autocorrect import Speller
spell = Speller(lang='en')



#  "Wordnet" tool is used for computational linguistics and natural language processing.
#  "WordNet" is a freely available "lexical English database" that can be used to generate semantic[Actual meaning] relationships between words. 
nltk.download('wordnet')



# ------------------------- Miscellaneous -------------------------

# Library used for detecting "strings"
import string

# "RegEx / Regular Expression" -> Sequence of characters that forms a "search pattern".
import re

# "WordCloud" is a technique to show which words are the most frequent among the given text
# !conda install -c conda-forge wordcloud
from wordcloud import WordCloud #STOPWORDS   # [conda install -c conda-forge wordcloud]



## ========================= For Options and Customization =========================

# To display all columns from dataframe
pd.pandas.set_option('display.max_columns', None)  # ‘None’ value means unlimited.
# To display all rows from dataframe
pd.pandas.set_option('display.max_rows', None)     # ‘None’ value means unlimited.
# To display max.width from dataframe
pd.pandas.set_option('display.width', None)        # ‘None’ value means unlimited.



## ========================= To Handle Warnings Messages =========================

# To prevent "warning" messages to be displayed
import warnings
warnings.filterwarnings(action='ignore',category=DeprecationWarning)
warnings.filterwarnings(action='ignore',category=FutureWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\19144\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\19144\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\19144\anaconda5
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-23.1.0               |   py39hcbf5309_0         912 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     wordcloud-1.8.2.2          |   py39hb82d6ee_0         187 KB  conda-forge
#     ------------------------------------------------------------
# ...

# %%
#Sentiment analysis lifecycle
from IPython.display import Image
Image(filename='download.png')

# %%
#Twitter breakdown
from IPython.display import Image
Image(filename='download (1).png')

# %%
#Process for breaking down text
from IPython.display import Image
Image(filename='download (2).png')

# %%
#Process for breaking down text continued
from IPython.display import Image
Image(filename='download (3).png')

# %%
#What is TF-IDF?
from IPython.display import Image
Image(filename='download (4).png')

# %%
#Process for breaking down text continued
from IPython.display import Image
Image(filename='download (5).png')

# %%
#Process breakdown overview
from IPython.display import Image
Image(filename='download (6).png')

# %%
TWITTER_HATE_SPEECH_PATH = "TwitterHate.csv"

# %%
# Define a function to load the "TwitterHate" dataset
def load_twitter_hate_speech_data(data_path = TWITTER_HATE_SPEECH_PATH): 
    csv_path = os.path.join(data_path, "TwitterHate.csv") 
    return pd.read_csv(csv_path , encoding="utf-8")

# %%
# Load the "Twitter Hate Speech" dataset
twitter_hate_speech_df = load_twitter_hate_speech_data()

# %%
# (rows, columns) --> Dataset dimensionality
twitter_hate_speech_df.shape

# %%
#Transpose of the dataset if required

twitter_hate_speech_df.head().T

# %%
# Make a copy of the original sourcefile
df = twitter_hate_speech_df.copy()

# %%
# Let's check the top 5 rows of our dataframe
df.head()

# %%
# Print the length of the dataset
print('length of data =', len(df))

# %%
# (rows, columns) --> Dataset dimensionality
df.shape

# %%
# Let's Load the columns names
df.columns

# %%
# let's inspect the type of variables in pandas

df.dtypes

# %%
# Let's print the type of variables available in our dataset

print(df.dtypes.value_counts())

# %%
# let's inspect the variable values

for var in df.columns:
    print(var, df[var].unique()[0:10], '\n')

# %%
# Now,Let's make a list of variable types.

# numerical: discrete vs continuous
discrete = [var for var in df.columns if df[var].dtype!='O'  and  df[var].nunique()<10]
continuous = [var for var in df.columns if df[var].dtype!='O'  and  var not in discrete]

# categorical
categorical = [var for var in df.columns if df[var].dtype=='O' ]

print('There are {} discrete variables'.format(len(discrete)))
print('There are {} continuous variables'.format(len(continuous)))
print('There are {} categorical variables'.format(len(categorical)))

# %%
# Now, Let's "Drop" the original variables which won't be useful in our Machine Learning Model.

df.drop(["id"], axis=1, inplace=True)

# %%
# Now, Let's view any one of the "tweets" randomly

random_tweet = np.random.randint(0,len(df))
print(random_tweet)
df.iloc[random_tweet]['tweet']

# %%
#Count the empty (NaN, NAN, na) values in each column

df.isnull().mean() *100

# %%
# Let's get the "information" available from the dataset
# The info() method is useful to get a quick description of the data
# in particular the total number of rows,
# and each attribute’s type and number of non-null values
df.info()

# %%
# Let's see how many "Twitter tweets having attribute 'label'" based on the Twitter Hate Speech Dataset, we have in our dataframe
df["label"].value_counts()

# %%
# Normalized value counts ( in %)
df["label"].value_counts(normalize=True) *100

# %%
# Plot the value counts with a bar graph (for visualization) using "Matplotlib"
plt.title('Twitter Hate Speech Analysis')
plt.xlabel('0 = Positive [+ve] Tweets (majority class) |  1 = Negative [-ve] Tweets (minority class)')  ; 
plt.ylabel('Frequency Count')
df["label"].value_counts().plot(kind="bar", color=["green","red"]);
                                              # colour links ==> https://matplotlib.org/3.1.0/gallery

# %%
#Visualize this count using "Seaborne"
sns.set_style('white')
plt.title("Twitter Hate Speech Analysis")
sns.countplot(df["label"],label="Frequency Count",palette="Spectral");
                                   # colour links ==> https://seaborn.pydata.org/tutorial/color_p

# %%
df["tweet"].to_list()[0:10]

# %%
# Get the tweets into a "LIST"

df_tweet_list = df["tweet"].values
df_tweet_list[0:5]

# %%
# Print the length of the dataset
len(df_tweet_list)

# %%
# Function used for Text Data Pre-processing
def preprocess_tweet_text(tweet):
    
    # Normalize the casing.
                      # [^A-Za-z]+ selects any character that matches the rule inside of the square bracket ([]), 
                      # that does not (^) have at least one (+) letter in upper case alphabets (A-Z) or 
                      # lower case alphabets (a-z) or 
                      # Numbers (0-9). Then the regex sub replaces these characters in the old text with space.
    tweet.lower()
    tweet = re.sub('[^A-Za-z0-9]+', ' ', tweet)
    
    # Remove user @ references and '#' from tweet
    tweet = re.sub(r'\@\w+ | \#','', tweet)
    
    # Remove urls
    tweet = re.sub(r"http\S+ | www\S+ | https\S+", '', tweet, flags=re.MULTILINE)
    
    # Remove punctuations from tweet - Efficiently using "Translate" method
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    
    #Using TweetTokenizer from NLTK, tokenize the tweets into individual terms.
    tk = TweetTokenizer()
    tweet_tokens = tk.tokenize(tweet)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_words = [w for w in tweet_tokens if not w in stop_words]
    
    # Remove redundant terms like ‘amp’, ‘rt’, etc.
    filtered_words_final = [w for w in filtered_words if not w in ('amp', 'rt')]
    
    return " ".join(filtered_words_final)

# %%
# Apply the pre-processing function for the "tweet" column
df["tweet"] = df["tweet"].apply(preprocess_tweet_text)

# %%
# Let's check the top 5 rows of our dataframe
df.head()

# %%
# Let's Create a new column - "Length"
df['length']= df['tweet'].apply(len)

# %%
# Let's check the top 5 rows of our dataframe
df.head()

# %%
# (rows, columns) --> Dataset dimensionality
df.shape

# %%
# Let's check the "Length" of the string and complete the task assigned.

# [a] If "Length" of the string = 0

len(df[df['length'] == 0])
print("The Number of Strings in the tweet column having Length = 0 is {}".format(len(df[df['length'] == 0]))) 

# [b] If "Length" of the string = 1

len(df[df['length'] == 1])
print("The Number of Strings in the tweet column having Length = 1 is {}".format(len(df[df['length'] == 1])))

# [c] If "Length" of the string > 1

len(df[df['length'] > 1])
print("The Number of Strings in the tweet column having Length > 1 is {}".format(len(df[df['length'] > 1])))

# %%
# Now, Remove tweets having length of 1 in our dataframe.

df = df[df["length"] > 1]

# %%
# (rows, columns) --> Dataset dimensionality
df.shape

# %%
# Let's check the top 5 rows of our dataframe
df.head()

# %%
# Function to Apply the "tokenization" process to the text corpus
def token_text(text):
    
    # Tokenize the text into a list of words
    tokens = nltk.tokenize.word_tokenize(text)
    return tokens

# %%
# Final list with "Tokenized words"
tokenized_terms = []

# Iterating over each string in the data
for x in df['tweet']:
    
    # Calling the pre-processed "text" function
    token = token_text(x)
    # Append them
    tokenized_terms.append(token)

# Create "All the tokenized terms" ---> "One Large List"
tokeninized_list = [i for j in tokenized_terms for i in j]

# %%
# Just cross-check the "Type" of "object" created for the text corpus
type(tokeninized_list)

# %%
# Create a "List Comprehension" using "Counter" Class 
most_common_words= [word for word, word_count in Counter(tokeninized_list).most_common(10)]

# Printing the Top 10 most common terms
print(most_common_words)

# %%
# create an "object" for Word Cloud
df_word_cloud = df['tweet'][20000:]

# Plot size in Matplotlib
plt.figure(figsize = (20,20))

# Define the pre-defined stopwords
stopwords = set(STOPWORDS)

# create an object with the name "word_cloud"
word_cloud = WordCloud(max_words = 1000 , width = 1600 , height = 900, collocations=False, stopwords=STOPWORDS).generate(" ".join(df_word_cloud))

# Display the "Word Cloud" as an Image
plt.imshow(word_cloud);

# %%
# Let's check the "Tokens" for the First tweet.
tokenized_terms[0]

# %%
# Join the "Tokens" back to form "Strings"
tokenized_terms = [' '.join(tweet) for tweet in tokenized_terms]

# %%
# Let's cross-check the "Joined Tokens" / "Strings" for the First tweet.
tokenized_terms[0]

# %%
# Print the length of the dataset
len(tokenized_terms)

# %%
# Split data into "X" and "y"

X = df["tweet"]

y = df["label"]

# %%
# Setup random seed for reproducibility
np.random.seed(42)

# Split into train & test set
X_train, X_test, y_train, y_test = train_test_split(X,  # independent variables
                                                    y,  # dependent variable
                                                    test_size=0.2)  # percentage of data to use for test set

# %%
# Instantiate with a maximum of 5000 terms in your vocabulary.
tfidf_vectorizer = TfidfVectorizer(max_features =5000)

# %%
# Fit and apply on the train set.
X_train = tfidf_vectorizer.fit_transform(X_train)

# %%
# Apply on the test set.
X_test = tfidf_vectorizer.transform(X_test)

# %%
# Let's check the "Shape" of the DataFrame after splitting it

# (rows, columns)
print(f"X_train:{X_train.shape}"),

print(f"X_test:{X_test.shape}")

# %%
# Instantiate "Logistic Regression" from sklearn with "default parameters"
lr_default_class_weights = LogisticRegression()

# %%
# Fit into the "train" data
lr_default_class_weights.fit(X_train, y_train)

# %%
# Make predictions for the train and the test set.
y_train_predict_default_class_weights = lr_default_class_weights.predict(X_train)
y_test_predict_default_class_weights = lr_default_class_weights.predict(X_test)

# %%
#Scikit-learn cheat-sheet
from IPython.display import Image
Image(filename='download (7).png')

# %%
# Accuracy of the "train" set

print("Accuracy on the Train Dataset : ", accuracy_score(y_train,y_train_predict_default_class_weights))

# %%
# Recall of the "train" set

print("Recall on the Train Dataset : ", recall_score(y_train, y_train_predict_default_class_weights))

# %%
# F1 - score of the "train" set

print("f1 - score on the Train Dataset : ", f1_score(y_train, y_train_predict_default_class_weights))

# %%
# Classification Report

print(classification_report(y_train, y_train_predict_default_class_weights))

# %%
# Calculate fpr, tpr and thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_test_predict_default_class_weights)

# Calculate roc_auc
roc_auc = auc(fpr, tpr)

# Plot the figure in the notebook
plt.figure()

# Plot ROC curve
plt.plot(fpr, tpr, color='orange', lw=1, label='ROC curve (area = %0.2f)' % roc_auc)
# Plot line with no predictive power (baseline)
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--', label='No Skill')

# Set the "x-limits" and "y-limits" of the current axes.
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

# Customize the plot
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - "Default Parameters"')
plt.legend(loc="lower right")
plt.show()

# %%
roc_auc_score(y_test, y_test_predict_default_class_weights)

print(f"AUC_GridSearchCV: {roc_auc_score(y_test, y_test_predict_default_class_weights) * 100:.2f}%")

# %%
# Let's see how many "Twitter tweets having attribute 'label'" based on the Twitter Hate Speech Dataset, we have in our dataframe
df["label"].value_counts()

# %%
# Normalized value counts ( in %)
df["label"].value_counts(normalize=True) *100

# %%
# Plot the value counts with a bar graph (for visualization) using "Matplotlib"
plt.title('Twitter Hate Speech Analysis')
plt.xlabel('0 = Positive [+ve] Tweets (majority class) |  1 = Negative [-ve] Tweets (minority class)')  ; 
plt.ylabel('Frequency Count')
df["label"].value_counts().plot(kind="bar", color=["green","red"]);
                                              # colour links ==> https://matplotlib.org/3.1.0/gallery/color/named_colors.html

# %%
#Visualize this count using "Seaborne"
sns.set_style('white')
plt.title("Twitter Hate Speech Analysis")
sns.countplot(df["label"],label="Frequency Count",palette="Spectral");
                                   # colour links ==> https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
# Instantiate "Logistic Regression" from sklearn --> To find the "class weights"
lr_adjust_class_weights_check = LogisticRegression(solver='liblinear')

#Setting the range for class weights
weights = np.linspace(0.0,0.99,200)

#Creating a dictionary grid for grid search
param_grid = {'class_weight': [{0:x, 1:1.0-x} for x in weights]}

#Fitting grid search to the train data with 5 folds
gridsearch_adjust = GridSearchCV(estimator= lr_adjust_class_weights_check, 
                                 param_grid= param_grid,
                                 cv=StratifiedKFold(), 
                                 n_jobs=-1,  # Set n_jobs to -1 to use all cores (NOTE: n_jobs=-1 is broken as of 8 Dec 2019, using n_jobs=1 works)
                                 scoring='f1', 
                                 verbose=2).fit(X_train, y_train) # print out progress

#Ploting the score for different values of weight
sns.set_style('whitegrid')
plt.figure(figsize=(12,8))
weight_data = pd.DataFrame({ 'score': gridsearch_adjust.cv_results_['mean_test_score'], 'weight': (1- weights)})
sns.lineplot(weight_data['weight'], weight_data['score'])
plt.xlabel('Weight for class 1 = Negative [-ve] Tweets (minority class)')
plt.ylabel('F1 score')
plt.xticks([round(i/10,1) for i in range(0,11,1)])
plt.title('Scoring for different class weights', fontsize=24)

# %%
# Adjust the "Appropriate Class" in the "Logistic Regression model"
lr_adjust_class_weights = LogisticRegression(solver='liblinear' , class_weight={0: 0.12, 1: 0.88})

# %%
# "Train" the model on the "train" set (i.e) Fit into  the "train" data
lr_adjust_class_weights.fit(X_train, y_train)

# %%
# Evaluate the predictions on the "train" set 
y_train_predict_adjust_class_weights = lr_adjust_class_weights.predict(X_train)

# %%
# Accuracy of the "train" set

print("Accuracy on the Train Dataset : ", accuracy_score(y_train,y_train_predict_adjust_class_weights

# %%
# Recall of the "train" set

print("Recall on the Train Dataset : ", recall_score(y_train, y_train_predict_adjust_class_weights))

# %%
# F1 - score of the "train" set

print("f1 - score on the Train Dataset : ", f1_score(y_train, y_train_predict_adjust_class_weights))

# %%
# Classification Report

print(classification_report(y_train, y_train_predict_adjust_class_weights))

# %%
# Evaluate the predictions on the "test" set 
y_test_predict_adjust_class_weights = lr_adjust_class_weights.predict(X_test)

# Calculate fpr, tpr and thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_test_predict_adjust_class_weights)

# Calculate roc_auc
roc_auc = auc(fpr, tpr)

# Plot the figure in the notebook
plt.figure()

# Plot ROC curve
plt.plot(fpr, tpr, color='orange', lw=1, label='ROC curve (area = %0.2f)' % roc_auc)
# Plot line with no predictive power (baseline)
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--', label='No Skill')

# Set the "x-limits" and "y-limits" of the current axes.
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

# Customize the plot
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - "Adjusted Class weights Parameters"')
plt.legend(loc="lower right")
plt.show()

# %%
roc_auc_score(y_test, y_test_predict_adjust_class_weights)

print(f"AUC_GridSearchCV: {roc_auc_score(y_test, y_test_predict_adjust_class_weights) * 100:.2f}%")

# %%
# Provide the parameter grid to choose for ‘C’ and ‘penalty’ parameters.

# Define the "C values" parameters
C_values = np.arange(0.5, 20.0, 0.5)

# Define the "Penalty values" parameters
penalty_values = ["l1", "l2"]

# Define the "Hyperparameter Grid" parameters
hyperparam_grid = {"penalty": penalty_values, "C": C_values }

# %%
# Instantiate "Logistic Regression" from sklearn with "Balanced class weight"

lr_balanced_class_weights = LogisticRegression(solver='liblinear' , class_weight='balanced')

# %%
#Fitting grid search to the train data with 5 folds and Fit into the "train" data

gridsearch_balanced = GridSearchCV(estimator= lr_balanced_class_weights, 
                                   param_grid= hyperparam_grid,
                                   cv=StratifiedKFold(4), # Stratified 4 fold cross-validation
                                   n_jobs=-1,  # Set n_jobs to -1 to use all cores (NOTE: n_jobs=-1 is broken as of 8 Dec 2019, using n_jobs=1 works)
                                   scoring='recall', 
                                   verbose=2).fit(X_train, y_train) # print out progress

# %%
# "Best" Parameters - "Recall"

print(f'Best recall: {gridsearch_balanced.best_score_} with param: {gridsearch_balanced.best_params_}')

# %%
# Instantiate "Logistic Regression" from sklearn with "Best Estimators and class weight"

lr_best_class_weights = LogisticRegression(solver='liblinear' , 
                                           #class_weight={0: 0.12, 1: 0.88} ,
                                           class_weight='balanced' ,
                                           C=0.5 , 
                                           penalty='l2' ,
                                           verbose=2)

# %%
# Fit into  the "train" set.

lr_best_class_weights.fit(X_train, y_train)

# %%
# To make predictions on the "test" set.

y_test_predict_best_class_weights = lr_best_class_weights.predict(X_test)

# %%
# Accuracy of the "test" set

print("Accuracy on the Test Dataset : ", accuracy_score(y_test , y_test_predict_best_class_weights))

# %%
# Recall of the "test" set

print("Recall on the Test Dataset : ", recall_score(y_test , y_test_predict_best_class_weights))

# %%
# F1 - score of the "test" set

print("f1 - score on the Test Dataset : ", f1_score(y_test , y_test_predict_best_class_weights))

# %%
# To make predictions on the "train" set.

y_train_predict_best_class_weights = lr_best_class_weights.predict(X_train)

# %%
# Classification Report - "Train" set

print(classification_report(y_train, y_train_predict_best_class_weights))

# %%
# Classification Report - "Test" set

print(classification_report(y_test, y_test_predict_best_class_weights))

# %%
#ROC curve - best estimators and class weight
# Calculate fpr, tpr and thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_test_predict_best_class_weights)

# Calculate roc_auc
roc_auc = auc(fpr, tpr)

# Plot the figure in the notebook
plt.figure()

# Plot ROC curve
plt.plot(fpr, tpr, color='orange', lw=1, label='ROC curve (area = %0.2f)' % roc_auc)
# Plot line with no predictive power (baseline)
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--', label='No Skill')

# Set the "x-limits" and "y-limits" of the current axes.
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

# Customize the plot
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - "Best Estimators"')
plt.legend(loc="lower right")
plt.show()

# %%
roc_auc_score(y_test, y_test_predict_best_class_weights)

print(f"AUC_GridSearchCV: {roc_auc_score(y_test, y_test_predict_best_class_weights) * 100:.2f}%")

# %%
#Tips to further improve the "Current Model" further
#Feature Engineering: For simplicity, we have used only the given "Independent" variables. We can try creating new features like frequency-based, by grouping features etc for further analysis of the tweets.
#Tuning the threshold: By default, the threshold is 0.5 for all algorithms. We can try different values for the threshold and can find the optimal value by using a grid search or randomize search.
#Using Advanced Algorithms: For this explanation, we have used only logistic regression[L.R]. We can try different Advanced Bagging and Boosting Algorithms. And finally can also try stacking or blending the multiple algorithms..
